# %%
from fer import FER
import cv2
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %% [markdown]
# # Using FER

# %%
emotion_detector = FER(mtcnn=True)

# %%
# Loading an image
img = image.load_img("capture.JPG")
plt.imshow(img)
test_img = cv2.imread("capture.JPG")
analysis = emotion_detector.detect_emotions(test_img)
dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img)
print(dominant_emotion, emotion_score)
# Out:
# ...
# 3/3 [==============================] - 0s 16ms/step
# neutral 0.54

# %%
img = image.load_img("capture1.JPG")
plt.imshow(img)
test_img1 = cv2.imread("capture1.JPG")
analysis1 = emotion_detector.detect_emotions(test_img1)
dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img1)
print(dominant_emotion, emotion_score)
print(analysis1)
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step
# neutral 0.75
# [{'box': [2935, 442, 315, 368], 'emotions': {'angry': 0.01, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.21, 'sad': 0.02, 'surprise': 0.0, 'neutral': 0.75}}, {'box': [2168, 145, 357, 442], 'emotions': {'angry': 0.04, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.9, 'sad': 0.02, 'surprise': 0.03, 'neutral': 0.01}}]

# %%
img = image.load_img("capture2.JPG")
plt.imshow(img)
test_img2 = cv2.imread("capture2.JPG")
analysis2 = emotion_detector.detect_emotions(test_img2)
analysis2
dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img2)
print(dominant_emotion, emotion_score)
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# happy 1.0

# %%
img = image.load_img("capture3.JPG")
plt.imshow(img)
test_img3 = cv2.imread("capture3.JPG")
analysis3 = emotion_detector.detect_emotions(test_img3)
analysis3
dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img3)
print(dominant_emotion, emotion_score)
# Out:
# ...
# 3/3 [==============================] - 0s 12ms/step
# neutral 0.49

# %% [markdown]
# # Using Deepface

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\Rashmi Dsouza /.deepface created
# Directory  C:\Users\Rashmi Dsouza /.deepface/weights created

# %%
face_analysis = DeepFace.analyze(img_path = "capture.jpg")
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Rashmi Dsouza\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:01<00:00, 3.90MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Rashmi Dsouza\.deepface\weights\age_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 539M/539M [00:45<00:00, 11.8MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Rashmi Dsouza\.deepface\weights\gender_model_weights.h5
# ...

# %%
face_analysis = DeepFace.analyze(img_path = "capture1.jpg")
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.42it/s]

# %%
print(face_analysis["emotion"])
print(face_analysis["dominant_emotion"])
# Out:
# {'angry': 77.63205766677856, 'disgust': 2.714662983294147e-06, 'fear': 0.004709704080596566, 'happy': 22.354817390441895, 'sad': 0.00750746185076423, 'surprise': 3.5162878475603065e-05, 'neutral': 0.0008680262908455916}
# angry

# %%
face_analysis = DeepFace.analyze(img_path = "capture.jpg")
print(face_analysis["emotion"])
print(face_analysis["dominant_emotion"])
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.57it/s]
# {'angry': 1.3079543887511613e-06, 'disgust': 4.312673564421196e-11, 'fear': 42.913500319302045, 'happy': 0.29243087635268256, 'sad': 0.0064645529643513455, 'surprise': 5.557097577202609, 'neutral': 51.230501981913804}
# neutral
