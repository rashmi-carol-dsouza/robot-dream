# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Rashmi Dsouza/.cache\torch\hub\ultralytics_yolov5_master
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# ...
#
# requirements: 2 packages updated per C:\Users\Rashmi Dsouza\.cache\torch\hub\ultralytics_yolov5_master\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2022-12-12 Python-3.9.7 torch-1.12.1+cpu CPU
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 50 --data coco.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'E:\Emerging': No such file or directory
# YOLOv5  2022-12-14 Python-3.10.5 torch-1.13.0+cpu CPU
#
# ...

# %%
path = 'data/labels/val' #path of labels
labels = os.listdir(path)
for x in labels:
    with open(path+"/"+x) as f:
        lines = f.read().splitlines()
    for y in lines:
        if y[:1]!='0':
            with open(path+"/"+x,"w") as file:
                y[:1].replace('1',"0")

# %%
path = 'data/labels/val' #path of labels
labels = os.listdir(path)
for x in labels:
    with open(path+"/"+x) as f:
        lines = f.read().splitlines()
    for y in lines:
        if y[:1]!='0':
            print(x)

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
import torch
#model = torch.hub.load('.', 'custom', path='yolov5/runs/train/exp8/weights/best.pt', source='local') 
model = torch.hub.load('yolov5','custom', path='yolov5/runs/train/exp4/weights/best.pt',force_reload=True,source='local')

# Image
img = "Result/results/henley-design-studio-2ywzLqu-cuk-unsplash1.jpg"
# Inference
results = model(img)
# Results, change the flowing to: results.show()
# results.show()  # or .show(), .save(), .crop(), .pandas(), etc
# results.save(save_dir='results') 
# print(results.crop())
# print(results.pandas())
# print(results.pandas().xyxy[0])
print(results.pandas().xyxy[0].value_counts('name'))
# Out:
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# ...
#
# requirements: 2 packages updated per E:\Emerging AI\Project\Yolo\yolo exp 2\yolov5\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2022-12-15 Python-3.9.7 torch-1.12.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...
# name
# balloon    1
# dtype: int64

# %%
# !cd yolov5 && python val.py --batch 16 --data coco.yaml --weights best.pt --task test
# Out:
# loading annotations into memory...
# val: data=E:\Emerging AI\Project\yolo exp 2\yolov5\data\coco.yaml, weights=['best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'E:\Emerging': No such file or directory
# YOLOv5  2022-12-15 Python-3.10.5 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning E:\Emerging AI\Project\yolo exp 2\data\labels\val.cache... 414 images, 8 backgrounds, 0 corrupt: 100%|##########| 414/414 [00:00<?, ?it/s]
# test: Scanning E:\Emerging AI\Project\yolo exp 2\data\labels\val.cache... 414 images, 8 backgrounds, 0 corrupt: 100%|##########| 414/414 [00:00<?, ?it/s]
#
# ...

# %%
# !cd yolov5 && python val.py --batch 16 --data coco.yaml --weights best.pt --task train
# Out:
# loading annotations into memory...
# val: data=E:\Emerging AI\Project\yolo exp 2\yolov5\data\coco.yaml, weights=['best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=train, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'E:\Emerging': No such file or directory
# YOLOv5  2022-12-15 Python-3.10.5 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# train: Scanning E:\Emerging AI\Project\yolo exp 2\data\labels\train...:   0%|          | 0/2245 [00:00<?, ?it/s]
# train: Scanning E:\Emerging AI\Project\yolo exp 2\data\labels\train... 1 images, 1 backgrounds, 0 corrupt:   0%|          | 1/2245 [00:05<3:12:25,  5.15s/it]
# ...
